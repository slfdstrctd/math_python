# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import linalg

# %%
def f(x):
    return np.sin(x/5) * np.exp(x/10) + 5 * np.exp(-x/2)

# %%
def g(x,w):
    return sum([w[i] * x ** i for i,k in enumerate(w)])

# %%
x = np.array([1,4,10, 15])
n = len(nodes)

xx = np.linspace(1,15)


A = np.array([x ** i for i in range(n) 
    for x in nodes]).reshape((n,n)).T

print(A)

b = np.array([f(x[i]) for i in range(n)])
print(b)

coeffs = linalg.solve(A,b)

print(coeffs)


plt.plot(xx, f(xx))
plt.plot(xx, g(xx, coeffs))

f = open("submission-2.txt", "w")
f.write("%f %f %f %f" % (coeffs[0],coeffs[1],coeffs[2],coeffs[3]))
f.close()
# Out:
# [[   1    1    1    1]
#  [   1    4   16   64]
#  [   1   10  100 1000]
#  [   1   15  225 3375]]
# [3.25221687 1.74684595 2.50541641 0.63522142]
# [ 4.36264154 -1.29552587  0.19333685 -0.00823565]
